# %%
from flask import Flask,render_template,url_for,request
import re
import pandas as pd
import spacy
from spacy import displacy
import en_core_web_sm
nlp = spacy.load('en_core_web_sm')

# %%
app = Flask(__name__)

@app.route('/')
def index():
    return render_template("index.html")

# %%
@app.route('/process',methods=["POST"])
def process():
    if request.method == 'POST':
        choice = request.form['taskoption']
        rawtext = request.form['rawtext']
        doc = nlp(rawtext)
        d = []
        for ent in doc.ents:
            d.append((ent.label_, ent.text))
            df = pd.DataFrame(d, columns=('named entity', 'output'))
            ORG_named_entity = df.loc[df['named entity'] == 'ORG']['output']
            PERSON_named_entity = df.loc[df['named entity'] == 'PERSON']['output']
            GPE_named_entity = df.loc[df['named entity'] == 'GPE']['output']
            MONEY_named_entity = df.loc[df['named entity'] == 'MONEY']['output']
            FAC_named_entity = df.loc[df['named entity'] == 'FAC']['output']
            PRODUCT_named_entity = df.loc[df['named entity'] == 'PRODUCT']['output']
            EVENT_named_entity = df.loc[df['named entity'] == 'EVENT']['output']
        if choice == 'organization':
            results = ORG_named_entity
            num_of_results = len(results)
        elif choice == 'person':
            results = PERSON_named_entity
            num_of_results = len(results)
        elif choice == 'geopolitical':
            results = GPE_named_entity
            num_of_results = len(results)
        elif choice == 'money':
            results = MONEY_named_entity
            num_of_results = len(results)
        elif choice == 'fact':
            results = FAC_named_entity
            num_of_results = len(results)
        elif choice == 'topic':
            results = PRODUCT_named_entity
            num_of_results = len(results)
        elif choice == 'event':
            results = EVENT_named_entity
            num_of_results = len(results)

    return render_template("index.html",results=results,num_of_results = num_of_results)

# %%
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [06/Jul/2020 15:00:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:00:49] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:00:49] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:01:17] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:01:17] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:01:17] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:01:28] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:01:28] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:01:28] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:01:37] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:01:38] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:01:38] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:01:47] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:01:47] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:01:47] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:04:40] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:04:40] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:04:40] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:04:46] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:04:46] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:04:46] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:04:54] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:04:54] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:04:54] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:05:01] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:05:01] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:05:01] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:05:08] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:05:08] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:05:08] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:05:15] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:05:15] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:05:15] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:05:23] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:05:23] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:05:23] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:05:29] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:05:29] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:05:29] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:05:36] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:05:36] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:05:36] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:38:51] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:38:51] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:38:51] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:39:04] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:39:04] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:39:04] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:39:13] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:39:13] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:39:13] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:39:20] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:39:20] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:39:20] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:39:27] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:39:27] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:39:27] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:39:36] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:39:37] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:39:37] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:39:43] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:39:43] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:39:43] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:40:35] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:40:35] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:40:35] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:40:45] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:40:45] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:40:45] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:40:58] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:40:58] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:40:58] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:41:08] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:41:08] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:41:08] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:41:16] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:41:16] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:41:16] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:41:22] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:41:22] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:41:22] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:41:33] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:41:33] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:41:33] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:41:50] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:41:50] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:41:50] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:42:06] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:42:07] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:42:07] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:42:23] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:42:23] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:42:23] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:42:39] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 15:42:39] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 15:42:39] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 16:00:20] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jul/2020 16:00:20] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jul/2020 16:00:20] "GET /main.js HTTP/1.1" 404 -
