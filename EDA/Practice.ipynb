# %%
import pandas as pd
import numpy as np

# %%
team =pd.read_excel('D:/IPL/IPL Data/Team.xlsx')
team.head(3)
# Out:
#    Team_Id                    Team_Name Team_Short_Code
# 0        1        Kolkata Knight Riders             KKR
# 1        2  Royal Challengers Bangalore             RCB
# 2        3          Chennai Super Kings             CSK

# %%
season =pd.read_excel('D:/IPL/IPL Data/Season.xlsx')
season.head(3)
# Out:
#    Season_Id  Season_Year  Orange_Cap_Id  Purple_Cap_Id  Man_of_the_Series_Id
# 0          1         2008            100            102                    32
# 1          2         2009             18             61                    53
# 2          3         2010            133            131                   133

# %%
player_match=pd.read_excel('D:/IPL/IPL Data/Player_match.xlsx')
player_match.head()
# Out:
#    Match_Id  Player_Id  Team_Id  Is_Keeper  Is_Captain
# 0    335987          1        1          0           1
# 1    335987          2        1          0           0
# 2    335987          3        1          0           0
# 3    335987          4        1          0           0
# 4    335987          5        1          0           0

# %%
player = pd.read_excel('D:/IPL/IPL Data/Player.xlsx')
player.head()
# Out:
#    Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0          1       SC Ganguly 1972-07-08    Left_Hand    Right-arm medium
# 1          2      BB McCullum 1981-09-27   Right_Hand    Right-arm medium
# 2          3       RT Ponting 1974-12-19   Right_Hand    Right-arm medium
# 3          4        DJ Hussey 1977-07-15   Right_Hand  Right-arm offbreak
# 4          5  Mohammad Hafeez 1980-10-17   Right_Hand  Right-arm offbreak
#
#        Country  Is_Umpire  Unnamed: 7
# 0        India          0         NaN
# 1  New Zealand          0         NaN
# 2    Australia          0         NaN
# 3    Australia          0         NaN
# 4     Pakistan          0         NaN

# %%
match=pd.read_excel('D:/IPL/IPL Data/Match.xlsx')
match.columns
# Out:
# Index(['Match_Id', 'Match_Date', 'Team_Name_Id', 'Opponent_Team_Id',
#        'Season_Id', 'Venue_Name', 'Toss_Winner_Id', 'Toss_Decision',
#        'IS_Superover', 'IS_Result', 'Is_DuckWorthLewis', 'Win_Type', 'Won_By',
#        'Match_Winner_Id', 'Man_Of_The_Match_Id', 'First_Umpire_Id',
#        'Second_Umpire_Id', 'City_Name', 'Host_Country'],
#       dtype='object')

# %%
ball_by_ball =pd.read_excel('D:/IPL/IPL Data/Ball_by_Ball.xlsx')
ball_by_ball.head(3)
# Out:
#    Match_Id  Season_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 0    335987          1           1        1        1                1
# 1    335987          1           1        1        2                1
# 2    335987          1           1        1        3                1
#
#    Team_Bowling_Id  Striker_Id  Striker_Batting_Position  Non_Striker_Id  \
# 0                2           1                         1               2
# 1                2           2                         2               1
# 2                2           2                         2               1
#
#    Bowler_Id  Batsman_Scored Extra_Type Extra_Runs Player_dissimal_Id  \
# 0         14               0    legbyes          1
# 1         14               0
# 2         14               0      wides          1
#
#   Dissimal_Type Fielder_Id
# 0
# 1
# 2

# %%
# Number of matches won by each team in IPL histroy?

won_by_each_team=pd.merge(team,match,left_on="Team_Id",right_on='Team_Name_Id')
won_by_each_team.head()
# Out:
#    Team_Id              Team_Name Team_Short_Code  Match_Id Match_Date  \
# 0        1  Kolkata Knight Riders             KKR    335991 2008-04-20
# 1        1  Kolkata Knight Riders             KKR    336002 2008-04-29
# 2        1  Kolkata Knight Riders             KKR    336015 2008-05-08
# 3        1  Kolkata Knight Riders             KKR    336022 2008-05-13
# 4        1  Kolkata Knight Riders             KKR    336030 2008-05-18
#
#    Team_Name_Id  Opponent_Team_Id  Season_Id    Venue_Name  Toss_Winner_Id  \
# 0             1                 8          1  Eden Gardens               8
# 1             1                 7          1  Eden Gardens               1
# 2             1                 2          1  Eden Gardens               1
# 3             1                 6          1  Eden Gardens               1
# 4             1                 3          1  Eden Gardens               1
#
#    ... IS_Result  Is_DuckWorthLewis    Win_Type  Won_By Match_Winner_Id  \
# ...

# %%
won_by_team=won_by_each_team.groupby('Team_Name')['Match_Winner_Id'].count()
won_by_team
# Out:
# Team_Name
# Chennai Super Kings            74
# Deccan Chargers                39
# Delhi Daredevils               68
# Gujarat Lions                   9
# Kings XI Punjab                65
# Kochi Tuskers Kerala            7
# Kolkata Knight Riders          62
# Mumbai Indians                 62
# Pune Warriors                  23
# Rajasthan Royals               52
# Rising Pune Supergiants         7
# Royal Challengers Bangalore    76
# Sunrisers Hyderabad            30
# Name: Match_Winner_Id, dtype: int64
