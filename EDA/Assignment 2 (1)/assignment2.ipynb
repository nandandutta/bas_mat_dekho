# %%
import pandas as pd
import numpy as np

# %%
calender=pd.read_csv('calendar.csv')
listings=pd.read_csv('listings.csv')
neighbour=pd.read_csv('neighbourhoods.csv')
reviews=pd.read_csv('reviews.csv')
listings_brief=pd.read_csv('listings_brief.csv')
reviews_brief=pd.read_csv('reviews_brief.csv')

# %%
calender.head()
# Out:
#    listing_id        date available   price
# 0      635756  2019-11-14         t  $67.00
# 1      292285  2019-11-14         f     NaN
# 2      292285  2019-11-13         f     NaN
# 3      292285  2019-11-12         f     NaN
# 4      292285  2019-11-11         f     NaN

# %%
pd.set_option('display.max_columns',None)
listings.head(2)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0     6     https://www.airbnb.com/rooms/6  20181115100559   2018-11-15
# 1  5570  https://www.airbnb.com/rooms/5570  20181115100559   2018-11-15
#
#                                              name  \
# 0  Large Craftsmen w/ yard ~ Perfect for families
# 1                   Ocean front condo on the sand
#
#                                              summary  \
# 0  Our Beautiful Craftsmen house has all the mode...
# 1  Missionbeachretreat.   Great Ocean Front Condo...
#
#                                                space  \
# 0  We are located in the heart of North Park, the...
# 1  This charming two bedroom beachfront condomini...
#
#                                          description experiences_offered  \
# 0  Our Beautiful Craftsmen house has all the mode...                none
# 1  Missionbeachretreat.   Great Ocean Front Condo...                none
#
#                                neighborhood_overview  \
# 0  We have the best Neighborhood in San Diego, in...
# 1  While some may compare San Diego’s Mission Bea...
#
#                                                notes  \
# 0  The driveway has room for two cars to park tan...
# 1                                                NaN
#
#                                              transit  \
# 0  We are right around the corner from a bus stop...
# 1  Bus #8 goes to La Jolla and Old Town transit c...
#
#                                               access  \
# 0  Guests will have access to everything in the h...
# 1  2 Bedrooms (1 Queen, 2 Twins)  1 Bath Balcony ...
#
#                                          interaction  \
# 0  We will not be in town but you are welcome to ...
# 1  Once reservation is made I will call guest.  I...
#
#                                          house_rules  thumbnail_url  \
# 0  I know this is stated above but before you boo...            NaN
# 1  Min 4 nights winter.  7 nights Spring Break, l...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/22883194/5...
# 1         NaN  https://a0.muscache.com/im/pictures/d3342744-1...
#
#    xl_picture_url  host_id                                host_url  \
# 0             NaN       29    https://www.airbnb.com/users/show/29
# 1             NaN     8435  https://www.airbnb.com/users/show/8435
#
#                            host_name  host_since  \
# 0                               Sara  2008-03-03
# 1  Jef Karchin'S MISSIONBEACHRETREAT  2009-02-23
#
#                           host_location  \
# 0  San Diego, California, United States
# 1  San Diego, California, United States
#
#                                           host_about  host_response_time  \
# 0  I am a San Diego based Entrepreneur with a lov...      within an hour
# 1  Real estate broker,  Jef  Karchin real estate ...  within a few hours
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0               100%                   NaN                 t
# 1               100%                   NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/29/profile_pi...
# 1  https://a0.muscache.com/im/users/8435/profile_...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/29/profile_pi...         North Park
# 1  https://a0.muscache.com/im/users/8435/profile_...      Mission Beach
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
# 1                  3.0                        3.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'facebook', 'reviews', 'off...                    t
# 1                          ['email', 'phone', 'kba']                    t
#
#   host_identity_verified                        street  neighbourhood  \
# 0                      f  San Diego, CA, United States     North Park
# 1                      t  San Diego, CA, United States  Mission Beach
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed       city state  \
# 0            North Hills                           NaN  San Diego    CA
# 1            Mission Bay                           NaN  San Diego    CA
#
#    zipcode     market smart_location country_code        country   latitude  \
# 0  92104.0  San Diego  San Diego, CA           US  United States  32.753993
# 1  92109.0  San Diego  San Diego, CA           US  United States  32.784304
#
#     longitude is_location_exact property_type        room_type  accommodates  \
# 0 -117.129705                 t         House  Entire home/apt             6
# 1 -117.252578                 t   Condominium  Entire home/apt             6
#
#    bathrooms  bedrooms  beds  bed_type  \
# 0        2.0       3.0   4.0  Real Bed
# 1        1.0       2.0   4.0  Real Bed
#
#                                            amenities  square_feet      price  \
# 0  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...          NaN    $295.00
# 1  {TV,"Cable TV",Internet,Wifi,Kitchen,"Free par...        850.0  $2,050.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN            $0.00       $85.00                4
# 1          NaN           NaN          $500.00      $150.00                1
#
#   extra_people  minimum_nights  maximum_nights calendar_updated  \
# 0        $5.00               2              30      4 weeks ago
# 1        $0.00               3             365            today
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                8                8               20
# 1                t               30               49               60
#
#    availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 0                20            2018-11-15                149   2008-06-22
# 1               328            2018-11-15                  0          NaN
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 0  2018-10-07                  96.0                    10.0
# 1         NaN                   NaN                     NaN
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        9.0                   10.0
# 1                        NaN                    NaN
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                          NaN                     NaN                  NaN
#
#   requires_license  license  \
# 0                f      NaN
# 1                f      NaN
#
#                                   jurisdiction_names instant_bookable  \
# 0  {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...                t
# 1  {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               1               1.18
# 1                               2                NaN

# %%
neighbour.head()
# Out:
#    neighbourhood_group                neighbourhood
# 0                  NaN               Allied Gardens
# 1                  NaN                   Alta Vista
# 2                  NaN  Amphitheater And Water Park
# 3                  NaN                  Balboa Park
# 4                  NaN                  Bario Logan

# %%
reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0           6        8  2008-06-22          415      Terrence
# 1           6     4383  2009-06-22         3762     Christine
# 2           6  1722383  2012-07-16      1864778          Hieu
# 3           6  5595071  2013-07-07       117966        Daryna
# 4           6  5631156  2013-07-08      6563815        Mathew
#
#                                             comments
# 0  Sara is an awesome hostess.  She was very cons...
# 1  My stay at “Craftsmen” was wonderful!  Sara wa...
# 2  This was my first time using Airbnb and Sara m...
# 3  Sara was a very pleasant host! Reservation was...
# 4  Sara was such an amazing hostess! My girlfrien...

# %%
listings_brief.head()
# Out:
#       id                                            name  host_id  \
# 0      6  Large Craftsmen w/ yard ~ Perfect for families       29
# 1   5570                   Ocean front condo on the sand     8435
# 2   8095                            Sunset Cliffs Studio      270
# 3  39516                 Art Studio Retreat/Rustic Cabin   169649
# 4  45429                 OB cottage SD--view on waterway   197919
#
#                            host_name  neighbourhood_group neighbourhood  \
# 0                               Sara                  NaN   North Hills
# 1  Jef Karchin'S MISSIONBEACHRETREAT                  NaN   Mission Bay
# 2                              Marin                  NaN   Ocean Beach
# 3                    Chris  And Jean                  NaN   North Hills
# 4                            Melissa                  NaN   Loma Portal
#
#     latitude   longitude        room_type  price  minimum_nights  \
# 0  32.753993 -117.129705  Entire home/apt    295               2
# 1  32.784304 -117.252578  Entire home/apt   2050               3
# 2  32.735170 -117.243793  Entire home/apt     84               2
# 3  32.731884 -117.119180  Entire home/apt     69               3
# 4  32.748768 -117.229371  Entire home/apt    160               2
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                149  2018-10-07               1.18
# 1                  0         NaN                NaN
# 2                178  2015-11-02               1.56
# 3                338  2018-11-07               3.33
# 4                  6  2014-07-28               0.06
#
#    calculated_host_listings_count  availability_365
# 0                               1                20
# 1                               2               328
# 2                               1                 0
# 3                               1               273
# 4                               1               363

# %%
reviews_brief.head()
# Out:
#    listing_id        date
# 0           6  2008-06-22
# 1           6  2009-06-22
# 2           6  2012-07-16
# 3           6  2013-07-07
# 4           6  2013-07-08

# %%
#  Major factors to consider while booking the hotel
n=pd.DataFrame(listings_brief.columns)
n
# Out:
#                                  0
# 0                               id
# 1                             name
# 2                          host_id
# 3                        host_name
# 4              neighbourhood_group
# 5                    neighbourhood
# 6                         latitude
# 7                        longitude
# 8                        room_type
# 9                            price
# 10                  minimum_nights
# 11               number_of_reviews
# 12                     last_review
# 13               reviews_per_month
# 14  calculated_host_listings_count
# 15                availability_365

# %%
#  First cleaning the clander data
calender.nunique()
# Out:
# listing_id    11922
# date            371
# available         2
# price          2368
# dtype: int64

# %%
listings.isnull().sum()
# Out:
# id                                      0
# listing_url                             0
# scrape_id                               0
# last_scraped                            0
# name                                    2
# summary                               413
# space                                3160
# description                           153
# experiences_offered                     0
# neighborhood_overview                4329
# notes                                5652
# transit                              4842
# access                               4366
# interaction                          4601
# house_rules                          3462
# thumbnail_url                       11922
# medium_url                          11922
# picture_url                             0
# xl_picture_url                      11922
# host_id                                 0
# host_url                                0
# host_name                               6
# host_since                              6
# host_location                          56
# host_about                           3976
# host_response_time                   4013
# host_response_rate                   4013
# host_acceptance_rate                11922
# host_is_superhost                       6
# host_thumbnail_url                      6
#                                     ...
# extra_people                            0
# minimum_nights                          0
# maximum_nights                          0
# calendar_updated                        0
# has_availability                        0
# availability_30                         0
# availability_60                         0
# availability_90                         0
# availability_365                        0
# calendar_last_scraped                   0
# number_of_reviews                       0
# first_review                         2163
# last_review                          2160
# review_scores_rating                 2293
# review_scores_accuracy               2299
# review_scores_cleanliness            2295
# review_scores_checkin                2310
# review_scores_communication          2301
# review_scores_location               2313
# review_scores_value                  2315
# requires_license                        0
# license                             11874
# jurisdiction_names                    507
# instant_bookable                        0
# is_business_travel_ready                0
# cancellation_policy                     0
# require_guest_profile_picture           0
# require_guest_phone_verification        0
# calculated_host_listings_count          0
# reviews_per_month                    2163
# Length: 96, dtype: int64

# %%
listings.shape
# Out:
# (11922, 96)

# %% [markdown]
# As we have the neighbourhood we should first focus on the city

# %% [markdown]
# Drop columns with 90% or more missing data

# %%
drop_cols=[]
for i in listings.columns:
    if listings[i].isnull().sum()>10000:
        drop_cols.append(i)
print('no of clos : ',len(drop_cols))
print(drop_cols)
listings.drop(drop_cols,axis=1,inplace=True)
# Out:
# no of clos :  9
# ['thumbnail_url', 'medium_url', 'xl_picture_url', 'host_acceptance_rate', 'neighbourhood_group_cleansed', 'square_feet', 'weekly_price', 'monthly_price', 'license']

# %%
listings.shape
# Out:
# (11922, 87)

# %% [markdown]
# For listings_brief

# %%
listings_brief.isnull().sum()
# Out:
# id                                    0
# name                                  2
# host_id                               0
# host_name                             6
# neighbourhood_group               11922
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        2160
# reviews_per_month                  2163
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
listings_brief.shape
# Out:
# (11922, 16)

# %% [markdown]
# Dropping neighbourhood_group as it has all null values

# %%
listings_brief.drop('neighbourhood_group',axis=1,inplace=True)

# %%
listings_brief.shape
# Out:
# (11922, 15)

# %% [markdown]
# As city is our priority

# %%
listings.city.unique()
# Out:
# array(['San Diego', 'La Jolla', 'La Jolla ', 'Del Mar', 'Solana Beach',
#        'San Diego ', 'Chula Vista', 'Oceanside', 'University heights',
#        'Ocean Beach', 'la jolla', 'Mission Beach', 'San diego',
#        'La jolla', 'Lemon Grove', 'Ocean Beach, San Diego', 'LA JOLLA',
#        'Coronado', 'Escondido', 'Chula Vista ', 'La Jolla, San Diego',
#        'Alpine', 'La Mesa', 'SAN DIEGO', 'Del Mar Highlands ',
#        'San Diego, CA, United States', 'San Diego, California, US',
#        'سان دييغو', 'Pacific Beach', 'Chula Vista,', ' La Jolla',
#        'La Jolla Shores', 'Mission Bay', 'Bonita', 'Newport Beach',
#        'Santee', 'National City', 'Gas lamp San Diego', 'Pacific Beach ',
#        'San DIego', 'CA', 'Chula Vista (Eastlake)', 'SanDiego',
#        'Spring Valley', 'Tijuana', 'Sandiego', 'Imperial Beach'],
#       dtype=object)

# %%
listings['price'] = listings['price'].replace('[\$,]','',regex=True).astype(float)

# %%
listing=pd.merge(listings,listings_brief)

# %%
listing.city.replace( 'La Jolla ', 'La Jolla',inplace = True)
listing.city.replace( 'la jolla', 'La Jolla',inplace = True)
listing.city.replace( 'La jolla', 'La Jolla',inplace = True)
listing.city.replace( 'LA JOLLA', 'La Jolla',inplace = True)
listing.city.replace( 'La Jolla, San Diego', 'La Jolla',inplace = True)
listing.city.replace( 'La Jolla Shores', 'La Jolla',inplace = True)
listing.city.replace( ' La Jolla', 'La Jolla',inplace = True)
listing.city.replace( 'SAN DIEGO', 'San Diego',inplace = True)
listing.city.replace( 'San Diego, California, US', 'San Diego',inplace = True)
listing.city.replace( 'San Diego ', 'San Diego',inplace = True)
listing.city.replace( 'San diego ', 'San Diego',inplace = True)
listing.city.replace( 'Ocean Beach, San Diego', 'Ocean Beach',inplace = True)
listing.city.replace( 'San diego', 'San Diego',inplace = True)
listing.city.replace( 'Pacific Beach ', 'Pacific Beach',inplace = True)
listing.city.replace( 'Del Mar Highlands ', 'Del Mar',inplace = True)
listing.city.unique()
# Out:
# array(['La Jolla', 'San Diego', 'Del Mar', 'Ocean Beach', 'La Mesa',
#        'Alpine', 'سان دييغو', 'Pacific Beach', 'Newport Beach',
#        'Gas lamp San Diego', 'National City', 'CA', 'Solana Beach'],
#       dtype=object)

# %%
listing.shape
# Out:
# (5327, 87)

# %%
listing.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   54001   https://www.airbnb.com/rooms/54001  20181115100559   2018-11-15
# 1   62274   https://www.airbnb.com/rooms/62274  20181115100559   2018-11-15
# 2   62949   https://www.airbnb.com/rooms/62949  20181115100559   2018-11-15
# 3  103417  https://www.airbnb.com/rooms/103417  20181115100559   2018-11-15
# 4  103420  https://www.airbnb.com/rooms/103420  20181115100559   2018-11-15
#
#                                              name  \
# 0      La Jolla Peaceful: Sitting Room, Breakfast
# 1              charming, colorful, close to beach
# 2  Pacific Beach Cozy Bright Private Unit w Bikes
# 3          La Jolla Retreat-Garden View-Breakfast
# 4       La Jolla Serene: Private Patio, Breakfast
#
#                                              summary  \
# 0                                                NaN
# 1  Modern, cozy, artsy, European in lush garden s...
# 2  Wonderful Cozy Private Retreat. Included are u...
# 3                                                NaN
# 4                                                NaN
#
#                                                space  \
# 0  The Peaceful is  one of two bedrooms in the de...
# 1  I am offering a big room with private entrance...
# 2  This unit is a wonderful cozy private little o...
# 3  The Retreat enjoys a queen size bed with down ...
# 4  The Serene is  one of two bedrooms in the deta...
#
#                                          description experiences_offered  \
# 0  The Peaceful is  one of two bedrooms in the de...                none
# 1  Modern, cozy, artsy, European in lush garden s...                none
# 2  Wonderful Cozy Private Retreat. Included are u...                none
# 3  The Retreat enjoys a queen size bed with down ...                none
# 4  The Serene is  one of two bedrooms in the deta...                none
#
#                                neighborhood_overview  \
# 0  Tranquility, stately trees, meditative, zen-fu...
# 1  We are in walking distance to Starbucks, Trade...
# 2  This is the best part of Pacific Beach, we are...
# 3  Tranquility, stately trees, meditative, zen-fu...
# 4  Mother Nature, walkability-bikeability, Calume...
#
#                                                notes  \
# 0  Also on Airbnb and available at the same prope...
# 1                                                NaN
# 2  STRICT NO SMOKING OF ANY KIND IN UNIT IF YOU D...
# 3  Also on Airbnb and available at the same prope...
# 4  When staying in the La Jolla Serene, one has t...
#
#                                              transit  \
# 0  If you are debating between renting a car or '...
# 1  We have bikes for you to get to the beach, but...
# 2  We provide 2 Beach Cruisers also main Bus line...
# 3  If you are debating between renting a car or '...
# 4  If you are debating between renting a car or '...
#
#                                               access  \
# 0                                  All common areas.
# 1  You have your own studio with private entrance...
# 2  2 Beach Cruisers, Cooler,  Beach Towels and Be...
# 3                                  All common areas.
# 4                                  All common areas.
#
#                                          interaction  \
# 0                As much or little as guests prefer.
# 1  I will leave enough space for the guests priva...
# 2  As much as is necessary. I am available 24/7 b...
# 3                       As much or little as desired
# 4             As much or as little as guest prefers.
#
#                                          house_rules  \
# 0  Available for responsible, independent, educat...
# 1  dear guests, Please open the bathroom window a...
# 2  No Smoking in Room but there is a little deck ...
# 3  Available for responsible, independent, educat...
# 4  Available for responsible, independent, educat...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/im/pictures/5e771b01-3...   252692
# 1  https://a0.muscache.com/im/pictures/84577734/9...   302986
# 2  https://a0.muscache.com/im/pictures/27127221/c...    21532
# 3  https://a0.muscache.com/im/pictures/56552093/0...   252692
# 4  https://a0.muscache.com/im/pictures/2695226/07...   252692
#
#                                    host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/252692    Marsha  2010-10-04
# 1  https://www.airbnb.com/users/show/302986    Isabel  2010-11-28
# 2   https://www.airbnb.com/users/show/21532      Lisa  2009-06-14
# 3  https://www.airbnb.com/users/show/252692    Marsha  2010-10-04
# 4  https://www.airbnb.com/users/show/252692    Marsha  2010-10-04
#
#                           host_location  \
# 0  San Diego, California, United States
# 1  San Diego, California, United States
# 2  San Diego, California, United States
# 3  San Diego, California, United States
# 4  San Diego, California, United States
#
#                                           host_about host_response_time  \
# 0  As a  La Jolla native, I have seen many change...     within an hour
# 1  i am originally from germany, but live since 1...     within an hour
# 2  I have a wonderful home in Pacific Beach, Cali...     within an hour
# 3  As a  La Jolla native, I have seen many change...     within an hour
# 4  As a  La Jolla native, I have seen many change...     within an hour
#
#   host_response_rate host_is_superhost  \
# 0               100%                 t
# 1               100%                 f
# 2               100%                 t
# 3               100%                 t
# 4               100%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/252692/profil...
# 1  https://a0.muscache.com/im/users/302986/profil...
# 2  https://a0.muscache.com/im/users/21532/profile...
# 3  https://a0.muscache.com/im/users/252692/profil...
# 4  https://a0.muscache.com/im/users/252692/profil...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/252692/profil...           La Jolla
# 1  https://a0.muscache.com/im/users/302986/profil...      Pacific Beach
# 2  https://a0.muscache.com/im/users/21532/profile...      Pacific Beach
# 3  https://a0.muscache.com/im/users/252692/profil...           La Jolla
# 4  https://a0.muscache.com/im/users/252692/profil...           La Jolla
#
#    host_listings_count  host_total_listings_count  \
# 0                  4.0                        4.0
# 1                  2.0                        2.0
# 2                  2.0                        2.0
# 3                  4.0                        4.0
# 4                  4.0                        4.0
#
#                                   host_verifications host_has_profile_pic  \
# 0               ['email', 'phone', 'reviews', 'kba']                    t
# 1               ['email', 'phone', 'reviews', 'kba']                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 3               ['email', 'phone', 'reviews', 'kba']                    t
# 4               ['email', 'phone', 'reviews', 'kba']                    t
#
#   host_identity_verified                        street  neighbourhood  \
# 0                      t   La Jolla, CA, United States       La Jolla
# 1                      t  San Diego, CA, United States  Pacific Beach
# 2                      f  San Diego, CA, United States  Pacific Beach
# 3                      t  La Jolla , CA, United States       La Jolla
# 4                      t   La Jolla, CA, United States       La Jolla
#
#   neighbourhood_cleansed       city state  zipcode     market smart_location  \
# 0               La Jolla   La Jolla    CA  92037.0  San Diego   La Jolla, CA
# 1          Pacific Beach  San Diego    CA  92109.0  San Diego  San Diego, CA
# 2          Pacific Beach  San Diego    CA  92109.0  San Diego  San Diego, CA
# 3               La Jolla   La Jolla    CA  92037.0  San Diego  La Jolla , CA
# 4               La Jolla   La Jolla    CA  92037.0  San Diego   La Jolla, CA
#
#   country_code        country   latitude   longitude is_location_exact  \
# 0           US  United States  32.811896 -117.269516                 t
# 1           US  United States  32.807337 -117.242432                 t
# 2           US  United States  32.809612 -117.230563                 t
# 3           US  United States  32.812803 -117.267470                 t
# 4           US  United States  32.812529 -117.267722                 t
#
#   property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0         House     Private room             2        1.0       1.0   1.0
# 1    Guesthouse  Entire home/apt             2        1.0       1.0   1.0
# 2   Guest suite  Entire home/apt             2        1.0       0.0   1.0
# 3         House     Private room             2        1.0       1.0   1.0
# 4         House     Private room             2        1.0       1.0   1.0
#
#    bed_type                                          amenities  price  \
# 0  Real Bed  {TV,"Cable TV",Wifi,Kitchen,Breakfast,"Free st...  105.0
# 1  Real Bed  {Wifi,"Air conditioning","Free parking on prem...   68.0
# 2  Real Bed  {TV,"Cable TV",Wifi,"Air conditioning","Pets a...   75.0
# 3  Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,Breakfast...  125.0
# 4  Real Bed  {TV,"Cable TV",Wifi,Kitchen,Breakfast,"Free st...  115.0
#
#   security_deposit cleaning_fee  guests_included extra_people  minimum_nights  \
# 0              NaN          NaN                1        $0.00               2
# 1          $100.00       $25.00                1       $10.00               2
# 2          $100.00       $20.00                1        $0.00               1
# 3              NaN          NaN                1        $0.00               2
# 4            $0.00        $0.00                1        $0.00               2
#
#    maximum_nights calendar_updated has_availability  availability_30  \
# 0             365       a week ago                t                0
# 1              30       a week ago                t                9
# 2              10            today                t               10
# 3             365            today                t                5
# 4             365       a week ago                t                4
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               13               43               304            2018-11-15
# 1               13               33               249            2018-11-15
# 2               25               43               119            2018-11-15
# 3               35               63                79            2018-11-15
# 4               22               52               160            2018-11-15
#
#    number_of_reviews first_review last_review  review_scores_rating  \
# 0                174   2011-01-04  2018-10-28                  98.0
# 1                460   2010-12-05  2018-10-30                  95.0
# 2                498   2012-08-23  2018-11-10                  97.0
# 3                145   2011-08-16  2018-09-30                  98.0
# 4                113   2011-11-10  2018-11-12                  98.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                    10.0                       10.0                   10.0
# 2                    10.0                       10.0                   10.0
# 3                    10.0                       10.0                   10.0
# 4                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                         10.0                    10.0                 10.0
# 2                         10.0                    10.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                    10.0                 10.0
#
#   requires_license                                 jurisdiction_names  \
# 0                f  {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...
# 1                f  {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...
# 2                f  {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...
# 3                f  {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...
# 4                f  {"SAN DIEGO"," SAN DIEGO TOURISM MARKETING DIS...
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                f                        f                     flexible
# 1                f                        f  strict_14_with_grace_period
# 2                t                        f                     moderate
# 3                f                        f                     flexible
# 4                f                        f                     flexible
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                t
# 1                             t                                t
# 2                             f                                f
# 3                             f                                t
# 4                             f                                t
#
#    calculated_host_listings_count  reviews_per_month
# 0                               4               1.82
# 1                               2               4.75
# 2                               2               6.56
# 3                               4               1.64
# 4                               4               1.32

# %%
#listing.isnull().sum()

# %%
listing.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed', 'city', 'state', 'zipcode',
#        'market', 'smart_location', 'country_code', 'country', 'latitude',
#        'longitude', 'is_location_exact', 'property_type', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
#        'amenities', 'price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights',
#        'calendar_updated', 'has_availability', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'calendar_last_scraped', 'number_of_reviews', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'requires_license', 'jurisdiction_names',
#        'instant_bookable', 'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# For calender

# %%
calender.head()
# Out:
#    listing_id        date available   price
# 0      635756  2019-11-14         t  $67.00
# 1      292285  2019-11-14         f     NaN
# 2      292285  2019-11-13         f     NaN
# 3      292285  2019-11-12         f     NaN
# 4      292285  2019-11-11         f     NaN

# %%
calender['price'] = calender['price'].replace('[\$,]','',regex=True).astype(float)

# %%
calender.head()
# Out:
#    listing_id        date available  price
# 0      635756  2019-11-14         t   67.0
# 1      292285  2019-11-14         f    NaN
# 2      292285  2019-11-13         f    NaN
# 3      292285  2019-11-12         f    NaN
# 4      292285  2019-11-11         f    NaN

# %%
# ratings vs pricing
listing.plot.scatter(y='price', x='review_scores_rating')

# %%
import seaborn as sns
# Distribution of price for listing
sns.distplot(listing["price"],axlabel="Distribution of price")

# %% [markdown]
# price mean

# %%
listing.price.mean()
# Out:
# 222.44659282898442

# %%
# pricing vs bathroom
sns.barplot(x = listing.bathrooms, y = listing.price)

# %%
# pricing vs bedroom
sns.barplot(x = listing.bedrooms, y = listing.price)

# %%
#  pricing vs no of persons can be accomodated
sns.barplot(x = listing.accommodates, y = listing.price)

# %%
# top 10 neighbourhood places preferred
listing.groupby("neighbourhood")["review_scores_rating"].sum().sort_values(ascending=False).head(10).plot(kind="bar")

# %%
# City has more price
listing.groupby('city')[['price']].sum().sort_values(by='price',ascending=False).head(10)
# Out:
#                    price
# city
# San Diego      1003508.0
# La Jolla        149662.0
# Del Mar          25557.0
# سان دييغو         2500.0
# Ocean Beach        855.0
# Pacific Beach      828.0
# La Mesa            758.0
# Alpine             462.0
# CA                 258.0
# Newport Beach      221.0

# %%
import seaborn as sns
sns.heatmap(listing.corr())

# %%
# super host vs rating
super_rating=listing.groupby("host_is_superhost")["review_scores_rating"].sum()
super_rating
# Out:
# host_is_superhost
# f    256954.0
# t    154503.0
# Name: review_scores_rating, dtype: float64

# %%
import matplotlib.pyplot as plt
labels=np.array(super_rating.index)
sizes=super_rating.values
colors=['white','green']
plt.figure(figsize=(5,3))
plt.pie(sizes,labels=labels,colors=colors,autopct='%1.1f%%')
plt.title('rating vs super host')
plt.axis('equal')
# Out:
# (-1.113394905140555,
#  1.1006378526257408,
#  -1.1209523614208017,
#  1.1129055247800441)

# %%
# property type vs price
listing.groupby("property_type")["price"].sum().reset_index().sort_values('price', ascending=False).head(5)
# Out:
#    property_type     price
# 17         House  580320.0
# 1      Apartment  251146.0
# 10   Condominium  132585.0
# 25     Townhouse   58936.0
# 27         Villa   38233.0
