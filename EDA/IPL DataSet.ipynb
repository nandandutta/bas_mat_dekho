# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
team =pd.read_excel('Team.xlsx')
team
# Out:
#     Team_Id                    Team_Name Team_Short_Code
# 0         1        Kolkata Knight Riders             KKR
# 1         2  Royal Challengers Bangalore             RCB
# 2         3          Chennai Super Kings             CSK
# 3         4              Kings XI Punjab            KXIP
# 4         5             Rajasthan Royals              RR
# 5         6             Delhi Daredevils              DD
# 6         7               Mumbai Indians              MI
# 7         8              Deccan Chargers              DC
# 8         9         Kochi Tuskers Kerala             KTK
# 9        10                Pune Warriors              PW
# 10       11          Sunrisers Hyderabad             SRH
# 11       12      Rising Pune Supergiants             RPS
# 12       13                Gujarat Lions              GL

# %%
season =pd.read_excel('Season.xlsx')
season.head()
# Out:
#    Season_Id  Season_Year  Orange_Cap_Id  Purple_Cap_Id  Man_of_the_Series_Id
# 0          1         2008            100            102                    32
# 1          2         2009             18             61                    53
# 2          3         2010            133            131                   133
# 3          4         2011            162            194                   162
# 4          5         2012            162            190                   315

# %%
player_match=pd.read_excel('Player_match.xlsx')
player_match.head()
# Out:
#    Match_Id  Player_Id  Team_Id  Is_Keeper  Is_Captain
# 0    335987          1        1          0           1
# 1    335987          2        1          0           0
# 2    335987          3        1          0           0
# 3    335987          4        1          0           0
# 4    335987          5        1          0           0

# %%
player = pd.read_excel('Player.xlsx')
player.head()
# Out:
#    Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0          1       SC Ganguly 1972-07-08    Left_Hand    Right-arm medium
# 1          2      BB McCullum 1981-09-27   Right_Hand    Right-arm medium
# 2          3       RT Ponting 1974-12-19   Right_Hand    Right-arm medium
# 3          4        DJ Hussey 1977-07-15   Right_Hand  Right-arm offbreak
# 4          5  Mohammad Hafeez 1980-10-17   Right_Hand  Right-arm offbreak
#
#        Country  Is_Umpire  Unnamed: 7
# 0        India          0         NaN
# 1  New Zealand          0         NaN
# 2    Australia          0         NaN
# 3    Australia          0         NaN
# 4     Pakistan          0         NaN

# %%
match=pd.read_excel('Match.xlsx')
match.head()
# Out:
#    Match_Id Match_Date  Team_Name_Id  Opponent_Team_Id  Season_Id  \
# 0    335987 2008-04-18             2                 1          1
# 1    335988 2008-04-19             4                 3          1
# 2    335989 2008-04-19             6                 5          1
# 3    335990 2008-04-20             7                 2          1
# 4    335991 2008-04-20             1                 8          1
#
#                                    Venue_Name  Toss_Winner_Id Toss_Decision  \
# 0                       M Chinnaswamy Stadium               2         field
# 1  Punjab Cricket Association Stadium, Mohali               3           bat
# 2                            Feroz Shah Kotla               5           bat
# 3                            Wankhede Stadium               7           bat
# 4                                Eden Gardens               8           bat
#
#    IS_Superover  IS_Result  Is_DuckWorthLewis    Win_Type  Won_By  \
# ...

# %%
ball_by_ball =pd.read_excel('Ball_by_Ball.xlsx')
ball_by_ball.head()
# Out:
#    Match_Id  Season_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 0    335987          1           1        1        1                1
# 1    335987          1           1        1        2                1
# 2    335987          1           1        1        3                1
# 3    335987          1           1        1        4                1
# 4    335987          1           1        1        5                1
#
#    Team_Bowling_Id  Striker_Id  Striker_Batting_Position  Non_Striker_Id  \
# 0                2           1                         1               2
# 1                2           2                         2               1
# 2                2           2                         2               1
# 3                2           2                         2               1
# 4                2           2                         2               1
#
#    Bowler_Id  Batsman_Scored Extra_Type Extra_Runs Player_dissimal_Id  \
# ...

# %%
player=pd.merge(player,ball_by_ball, left_on = 'Player_Id',right_on = 'Striker_Id')
player.head()
# Out:
#    Player_Id Player_Name        DOB Batting_Hand     Bowling_Skill Country  \
# 0          1  SC Ganguly 1972-07-08    Left_Hand  Right-arm medium   India
# 1          1  SC Ganguly 1972-07-08    Left_Hand  Right-arm medium   India
# 2          1  SC Ganguly 1972-07-08    Left_Hand  Right-arm medium   India
# 3          1  SC Ganguly 1972-07-08    Left_Hand  Right-arm medium   India
# 4          1  SC Ganguly 1972-07-08    Left_Hand  Right-arm medium   India
#
#    Is_Umpire  Unnamed: 7  Match_Id  Season_Id  ...  Striker_Id  \
# 0          0         NaN    335987          1  ...           1
# 1          0         NaN    335987          1  ...           1
# 2          0         NaN    335987          1  ...           1
# 3          0         NaN    335987          1  ...           1
# 4          0         NaN    335987          1  ...           1
#
#    Striker_Batting_Position  Non_Striker_Id  Bowler_Id  Batsman_Scored  \
# ...

# %%
#df_player["Extra_Runs"].groupby('Player_Name')["Extra_Runs"].count().sort_values(ascending=False)

# %% [markdown]
# what teams are deciding after winning the toss?

# %%
# we have toss decision in match df
Toss_decision = match.groupby(['Toss_Decision']).size().reset_index()

Toss_decision
# Out:
#   Toss_Decision    0
# 0           bat  262
# 1         field  315

# %%
# Lets rename the column
#Toss_decision.columns.values[0]='Number of Matches'

Toss_decision = Toss_decision.rename(columns= {0 : "Number of Matches"})

Toss_decision
# Out:
#   Toss_Decision  Number of Matches
# 0           bat                262
# 1         field                315

# %%
plt.pie(Toss_decision['Number of Matches'], labels=Toss_decision['Toss_Decision'], autopct='%.2f%%')

plt.show()

# %%
from matplotlib import pyplot as plt

# %%
# we have toss decision in match df
#Toss_decision = match.groupby(['Toss_Decision']).size().reset_index()
# Lets rename the column
#Toss_decision.columns.values[0]='Number of Matches'
#plt.pie(Toss_decision['Number of Matches'], labels=Toss_decision['Toss_Decision'], autopct='%.2f%%')
#plt.show()

# %% [markdown]
# which team has heighest AVg match aggregate?

# %%
df=pd.merge(team,match,left_on = 'Team_Id',right_on = 'Team_Name_Id')

# %%
df.groupby(['Team_Name']).size().reset_index().sort_values(by=0,ascending=False).head(5) #match.groupby(['Toss_Decision']).size().reset_index()
# Out:
#                       Team_Name   0
# 11  Royal Challengers Bangalore  78
# 0           Chennai Super Kings  74
# 2              Delhi Daredevils  69
# 4               Kings XI Punjab  65
# 6         Kolkata Knight Riders  62

# %%
df
# Out:
#      Team_Id                Team_Name Team_Short_Code  Match_Id Match_Date  \
# 0          1    Kolkata Knight Riders             KKR    335991 2008-04-20
# 1          1    Kolkata Knight Riders             KKR    336002 2008-04-29
# 2          1    Kolkata Knight Riders             KKR    336015 2008-05-08
# 3          1    Kolkata Knight Riders             KKR    336022 2008-05-13
# 4          1    Kolkata Knight Riders             KKR    336030 2008-05-18
# 5          1    Kolkata Knight Riders             KKR    336032 2008-05-20
# 6          1    Kolkata Knight Riders             KKR    336040 2008-05-25
# 7          1    Kolkata Knight Riders             KKR    392195 2009-04-23
# 8          1    Kolkata Knight Riders             KKR    392202 2009-04-27
# 9          1    Kolkata Knight Riders             KKR    392208 2009-05-01
# 10         1    Kolkata Knight Riders             KKR    392238 2009-05-20
# ...

# %% [markdown]
# Create a table containing team name scoring max runs

# %%
df2=pd.merge(df,ball_by_ball,left_on='Match_Id',right_on='Match_Id')

# %%
df2.groupby('Team_Name')['Match_Id']
# Out:
#    Team_Id              Team_Name Team_Short_Code  Match_Id Match_Date  \
# 0        1  Kolkata Knight Riders             KKR    335991 2008-04-20
# 1        1  Kolkata Knight Riders             KKR    335991 2008-04-20
# 2        1  Kolkata Knight Riders             KKR    335991 2008-04-20
#
#    Team_Name_Id  Opponent_Team_Id  Season_Id_x    Venue_Name  Toss_Winner_Id  \
# 0             1                 8            1  Eden Gardens               8
# 1             1                 8            1  Eden Gardens               8
# 2             1                 8            1  Eden Gardens               8
#
#    ... Striker_Id  Striker_Batting_Position  Non_Striker_Id  Bowler_Id  \
# 0  ...         53                         1              54        106
# 1  ...         54                         2              53        106
# 2  ...         54                         2              53        106
#
#   Batsman_Scored  Extra_Type  Extra_Runs  Player_dissimal_Id  Dissimal_Type  \
# ...

# %%
df2.columns
# Out:
# Index(['Team_Id', 'Team_Name', 'Team_Short_Code', 'Match_Id', 'Match_Date',
#        'Team_Name_Id', 'Opponent_Team_Id', 'Season_Id_x', 'Venue_Name',
#        'Toss_Winner_Id', 'Toss_Decision', 'IS_Superover', 'IS_Result',
#        'Is_DuckWorthLewis', 'Win_Type', 'Won_By', 'Match_Winner_Id',
#        'Man_Of_The_Match_Id', 'First_Umpire_Id', 'Second_Umpire_Id',
#        'City_Name', 'Host_Country', 'Season_Id_y', 'Innings_Id', 'Over_Id',
#        'Ball_Id', 'Team_Batting_Id', 'Team_Bowling_Id', 'Striker_Id',
#        'Striker_Batting_Position', 'Non_Striker_Id', 'Bowler_Id',
#        'Batsman_Scored', 'Extra_Type', 'Extra_Runs', 'Player_dissimal_Id',
#        'Dissimal_Type', 'Fielder_Id'],
#       dtype='object')
